# %%
import os
import cv2
import numpy as np
from tqdm import tqdm_notebook as tqdm
import tensorflow as tf
from skimage import io
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout,Flatten, Dense
from tensorflow.keras.models import model_from_json
import matplotlib.pyplot as plt

# %%
with open("dogsmodel_1.json","r") as jsonfile:
    model_json = jsonfile.read()
model = model_from_json(model_json)
model.load_weights('dogs_1.h5')

# %%
def detect(link,model):
    IMG_SIZE=64
    img = io.imread(link)
    img = cv2.resize(img,(IMG_SIZE, IMG_SIZE))
    img = img/255
    plt.imshow(img)
    if model.predict(np.array([img]))[0] == 1:
        print("It's a DOG!")
    else:
        print("Meowww. It's a CAT.")

# %%
urlDog = 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwO0nYBIPpoT5bHp9H0_9p7Ukr_TRX0MVYshDg2QSSS9_iVg9cCA'
urlCat = 'https://pbs.twimg.com/profile_images/378800000532546226/dbe5f0727b69487016ffd67a6689e75a_400x400.jpeg'
detect(urlCat,model)
# Out:
# Meowww. It's a CAT.
